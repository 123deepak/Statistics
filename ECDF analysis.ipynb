# %%
import numpy as np
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.pyplot as plt

# %%
data = [1,1,1,3,4,5,6,6,6,6,6,6,7,8,9]
ecdf = ECDF(data)

# %%
plt.plot(ecdf.x, ecdf.y)
plt.show()
